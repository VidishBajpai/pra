# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_kddcup99
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = fetch_kddcup99(percent10=True)
df = pd.DataFrame(data.data, columns=data.feature_names)
df['label'] = data.target

# %%
df
# Out:
#        duration protocol_type  ... dst_host_srv_rerror_rate       label
# 0             0        b'tcp'  ...                      0.0  b'normal.'
# 1             0        b'tcp'  ...                      0.0  b'normal.'
# 2             0        b'tcp'  ...                      0.0  b'normal.'
# 3             0        b'tcp'  ...                      0.0  b'normal.'
# 4             0        b'tcp'  ...                      0.0  b'normal.'
# ...         ...           ...  ...                      ...         ...
# 494016        0        b'tcp'  ...                      0.0  b'normal.'
# 494017        0        b'tcp'  ...                      0.0  b'normal.'
# 494018        0        b'tcp'  ...                      0.0  b'normal.'
# 494019        0        b'tcp'  ...                      0.0  b'normal.'
# 494020        0        b'tcp'  ...                      0.0  b'normal.'
#
# [494021 rows x 42 columns]

# %%
for col in df.columns :
    if df[col].dtype == 'object' :
        df[col] = LabelEncoder().fit_transform(df[col])

# %%
X = df.iloc[:, :-1]
X.head(3)
# Out:
#    duration  protocol_type  ...  dst_host_rerror_rate  dst_host_srv_rerror_rate
# 0         0              1  ...                     0                         0
# 1         0              1  ...                     0                         0
# 2         0              1  ...                     0                         0
#
# [3 rows x 41 columns]

# %%
model = IsolationForest(contamination=0.1, random_state=12)
model.fit(X)
# Out:
# IsolationForest(contamination=0.1, random_state=12)

# %%
pred = model.predict(X)

# %%
print('Total Records:', len(pred))
print("Anomalies detected:", np.sum(pred == -1))
print('Normal Records:', np.sum(pred == 1))
# Out:
# Total Records: 494021
# Anomalies detected: 49402
# Normal Records: 444619

# %%
plt.hist(pred, edgecolor='k')
plt.ylabel('#Count')
plt.title('1999 KDD Cup Anomaly Detection')
plt.xticks([-1,1],['Anomaly', 'Normal']);
